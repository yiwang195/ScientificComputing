# %% [markdown]
# # Introduction to GeoPandas
# http://geopandas.org/
# https://geohackweek.github.io/vector/06-geopandas-advanced/

# %% [markdown]
# ### GeoPandas data structures
# * GeoSeries
# * GeoDataFrame
#
# ### GepPandas geometric objects
# * Points/Multi-points
# * Lines/Multi-lines
# * Polygons/Multi-polygons

# %% [markdown]
# ## Reading & Writing  Files

# %%
#import the package
import geopandas as gpd

# %%
#enable plots to appear in the notebook
# %matplotlib inline

# %%
#read in the HUC12.shp feature class
gdf = gpd.read_file('../Data/HUC12.shp')

# %%
#How many features in the dataset?
len(gdf)
# Out:
# 210

# %%
#show the data types in this dataset
gdf.dtypes
# Out:
# OBJECTID_2      int64
# OBJECTID        int64
# HUC_8          object
# HUC_10         object
# HUC_12         object
# ACRES         float64
# NCONTRB_A     float64
# HU_10_GNIS     object
# HU_12_GNIS     object
# HU_10_DS       object
# HU_10_NAME     object
# HU_10_MOD      object
# HU_10_TYPE     object
# HU_12_DS       object
# HU_12_NAME     object
# HU_12_MOD      object
# HU_12_TYPE     object
# META_ID        object
# STATES         object
# GlobalID       object
# SHAPE_Leng    float64
# GAZ_ID          int64
# WBD_Date       object
# VPUID          object
# Shape_Le_1    float64
# Shape_STAr    float64
# Shape_STLe    float64
# geometry       object
# dtype: object

# %%
#examine the attributes for the first feature
gdf.iloc[0]
# Out:
# OBJECTID_2                                                80221
# OBJECTID                                                  58735
# HUC_8                                                  03040103
# HUC_10                                               0304010305
# HUC_12                                             030401030503
# ACRES                                                     15414
# NCONTRB_A                                                     0
# HU_10_GNIS
# HU_12_GNIS
# HU_10_DS                                             0304010306
# HU_10_NAME                                 Lower Uwharrie River
# HU_10_MOD                                                    NM
# HU_10_TYPE                                                    S
# HU_12_DS                                           030401030504
# HU_12_NAME                                         Barnes Creek
# HU_12_MOD                                                    NM
# HU_12_TYPE                                                    S
# META_ID                                                    NC01
# STATES                                                       NC
# GlobalID                 {49700E7B-2092-4648-976D-BDB9C5828120}
# SHAPE_Leng                                             0.458995
# GAZ_ID                                                  -396686
# WBD_Date                                             2012-02-01
# VPUID                                                       03N
# Shape_Le_1                                              0.45899
# Shape_STAr                                           0.00619584
# Shape_STLe                                              0.45899
# geometry      POLYGON ((-79.88965123981285 35.47995405243762...
# Name: 0, dtype: object

# %%
#show the first 5 values in the geometry field
gdf['geometry'][0:5]
# Out:
# 0    POLYGON ((-79.88965123981285 35.47995405243762...
# 1    POLYGON ((-80.06735036572678 35.56027136313293...
# 2    POLYGON ((-80.36849110927722 35.9302859922048,...
# 3    POLYGON ((-80.44931667272624 35.93854580294652...
# 4    POLYGON ((-80.32812167487538 34.87717135967057...
# Name: geometry, dtype: object

# %%
#show just the first value
gdf['geometry'][0]

# %%
#Plotting
gdf.plot(column='HUC_8',
         cmap='Paired',
         categorical=True,
         figsize=(14,18)
        );

# %%
#Dissolving
cols = []
huc8 =
