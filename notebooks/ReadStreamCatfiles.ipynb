# %% [markdown]
# ## Read streamcat data

# %%
import pandas as pd

# %%
fileName = '../Data/StreamCat/NLCD2006_NC.zip'

# %%
df = pd.read_csv(fileName,index_col='COMID')

# %%
df.head()
# Out:
#           CatAreaSqKm  WsAreaSqKm  CatPctFull  WsPctFull  PctOw2006Cat  \
# COMID
# 25955618       0.1683   2715.8274       100.0      100.0     16.577540
# 8680029        4.0923     34.3890       100.0      100.0     20.541016
# 8680033        0.7200      5.0850       100.0      100.0      8.750000
# 8673761        1.2267   4684.5945       100.0      100.0      6.896552
# 8680001        0.1053     14.2371       100.0      100.0      6.837607
#
#           PctIce2006Cat  PctUrbOp2006Cat  PctUrbLo2006Cat  PctUrbMd2006Cat  \
# COMID
# 25955618            0.0         0.000000         0.000000         0.000000
# 8680029             0.0         5.080273         4.068617         4.090609
# 8680033             0.0         4.000000         0.500000         0.000000
# 8673761             0.0         0.586941         0.146735         0.000000
# 8680001             0.0         0.000000         0.000000         0.000000
#
# ...
